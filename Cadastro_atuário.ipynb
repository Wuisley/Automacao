# %%
import pandas as pd
import pyautogui
import time
import pyperclip

# %%
t = 3

df = pd.read_excel("plano de amortização.xlsx", sheet_name= 9)
# Out:
#                CPF         Nome      Telefone                      E-mail  \
# 0   150.991.134-00  Toin do Gás  8.399863e+10  urtiotuieroute@hotmail.com
# 1              NaN          NaN           NaN                         NaN
# 2              NaN          NaN           NaN                         NaN
# 3              NaN          NaN           NaN                         NaN
# 4              NaN          NaN           NaN                         NaN
# 5              NaN          NaN           NaN                         NaN
# 6              NaN          NaN           NaN                         NaN
# 7              NaN          NaN           NaN                         NaN
# 8              NaN          NaN           NaN                         NaN
# 9              NaN          NaN           NaN                         NaN
# 10             NaN          NaN           NaN                         NaN
# 11             NaN          NaN           NaN                         NaN
# ...

# %% [markdown]
# Cadastro de Atuário

# %%
#CPF
time.sleep(t)
pyautogui.sleep(t)
pyperclip.copy(df.iloc[0,0])
pyautogui.hotkey('ctrl', 'a')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

pyautogui.press('space')
pyautogui.press('tab')

# %%
#Nome
pyautogui.sleep(t)
pyperclip.copy(str(df.iloc[0,1]))
pyautogui.hotkey('ctrl', 'a')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

# %%
#Telefone
time.sleep(t)
u = "0" + str(df.iloc[0,2])
pyperclip.copy(u)
pyautogui.hotkey('ctrl', 'a')
pyautogui.hotkey('ctrl', 'v')

pyautogui.press('tab')

# %%
#E-mail
pyautogui.sleep(t)
pyperclip.copy(str(df.iloc[0,3]))
pyautogui.hotkey('ctrl', 'a')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

# %%
#Enitadade Certificadora
pyautogui.sleep(t)
if df.iloc[0,4] != "nan":
    pyperclip.copy(df.iloc[0,4])
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')
else:
    pyautogui.press('tab')

# %%
#Validade da certificação
pyautogui.sleep(t)
if df.iloc[0,5] != "nan":
    pyperclip.copy(df.iloc[0,5])
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')
else:
    pyautogui.press('tab')

# %%
#Vínculo
pyautogui.sleep(t)
pyautogui.press('down')
pyautogui.press('up')

for n in range(int(df.iloc[0,6]-1)):
    pyautogui.press('down')
pyautogui.press('tab')

# %% [markdown]
# Registro Profissional do Atuário Responsável Técnico

# %%
#MTE
pyautogui.sleep(t)
pyperclip.copy(int(df.iloc[0,8]))
pyautogui.hotkey('ctrl', 'a')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

# %%
#IBA
pyautogui.sleep(t)
pyperclip.copy(int(df.iloc[0,9]))
pyautogui.hotkey('ctrl', 'a')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

# %% [markdown]
# Dados da empresa prestadora de Serviços Contratada pelo Ente ou pela Unidade Gestora do RPPS

# %%
#CNPJ
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    pyperclip.copy(df.iloc[0,10])
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')
    pyautogui.press('enter')
    pyautogui.press('tab')

# %%
#Nome
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    pyperclip.copy(str(df.iloc[0,11]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')

# %%
#Endereço
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    pyperclip.copy(str(df.iloc[0,12]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')

# %%
#Complemento
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3 and df.iloc[0,13] != 'nan':
    pyperclip.copy(str(df.iloc[0,13]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')
else:
    pyautogui.press('tab')

# %%
#Bairro
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    pyperclip.copy(str(df.iloc[0,14]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')

# %%
display(df.iloc[0,16])
# Out:
# 1

# %%
#Cidade
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    pyperclip.copy(str(df.iloc[0,15]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')

# %%
#UF
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    for n in range(int(df.iloc[0,16])):
        pyautogui.press('down')
    pyautogui.press('tab')

# %%
#CEP
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    pyperclip.copy(str(df.iloc[0,18]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')

# %%
#Telefone
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    time.sleep(t)
    u = "0" + str(df.iloc[0,19])
    pyperclip.copy(u)
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')

    pyautogui.press('tab')

# %%
#E-mail
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3:
    pyperclip.copy(str(df.iloc[0,20]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')

# %%
#CIBA
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3 and (df.iloc[0,21] != None or df.iloc[0,21] != "nan"):
    pyperclip.copy(str(df.iloc[0,21]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')
else:
    pyautogui.press('tab')

# %%
#Informação adicional
pyautogui.sleep(t)
if int(df.iloc[0,6]) == 3 and df.iloc[0,22] != None:
    pyperclip.copy(str(df.iloc[0,22]))
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.hotkey('ctrl', 'v')
    pyautogui.press('tab')
else:
    pyautogui.press('tab')
