# %%
#!pip install pyautogui
#!pip install opencv-python
#!pip install Openpyxl
#!pip install workbook
#!pip install pandas
#!pip install pywin32
#!pip install pyinstaller (para deixar o script executável)

# %%
import openpyxl as py
import pyautogui
import pyperclip #para conseguir usar texto com caracteres especiais
import time #para conseguir dar pausa em uma etapa específica
import pandas as pd
import pyperclip as pyper
#pyautogui.PAUSE = 1

# %%
df = pd.read_excel('plano de amortização.xlsx', sheet_name=0)
df
# Out:
#      ano  tx_juros       aportes  aliquotas  base_de_calculo tipo_amotizacao  \
# 0   2022     481.0  4.694553e+08     1966.0     2.387870e+09        aliquota
# 1   2023     481.0  9.593938e+08     3978.0     2.411749e+09             NaN
# 2   2024     481.0  1.462251e+09     6003.0     2.435867e+09             NaN
# 3   2025     481.0  1.528784e+09     6214.0     2.460225e+09             NaN
# 4   2026     481.0  1.596502e+09     6425.0     2.484827e+09             NaN
# 5   2027     481.0  1.665421e+09     6636.0     2.509676e+09             NaN
# 6   2028     481.0  1.735305e+09     6846.0     2.534773e+09             NaN
# 7   2029     481.0  1.752658e+09     6846.0     2.560120e+09             NaN
# 8   2030     481.0  1.770185e+09     6846.0     2.585721e+09             NaN
# 9   2031     481.0  1.787887e+09     6846.0     2.611579e+09             NaN
# 10  2032     481.0  1.805766e+09     6846.0     2.637694e+09             NaN
# 11  2033     481.0  1.823823e+09     6846.0     2.664071e+09             NaN
# 12  2034     481.0  1.842062e+09     6846.0     2.690712e+09             NaN
# 13  2035     481.0  1.860482e+09     6846.0     2.717619e+09             NaN
# 14  2036     481.0  1.879087e+09     6846.0     2.744795e+09             NaN
# 15  2037     481.0  1.897878e+09     6846.0     2.772243e+09             NaN
# 16  2038     481.0  1.916857e+09     6846.0     2.799966e+09             NaN
# 17  2039     481.0  1.936025e+09     6846.0     2.827965e+09             NaN
# 18  2040     481.0  1.955385e+09     6846.0     2.856245e+09             NaN
# 19  2041     481.0  1.974939e+09     6846.0     2.884808e+09             NaN
# 20  2042     481.0  1.994689e+09     6846.0     2.913656e+09             NaN
# 21  2043     481.0  2.014636e+09     6846.0     2.942792e+09             NaN
# 22  2044     481.0  2.034782e+09     6846.0     2.972220e+09             NaN
# 23  2045     481.0  2.055130e+09     6846.0     3.001942e+09             NaN
# 24  2046     481.0  2.075681e+09     6846.0     3.031962e+09             NaN
# 25  2047     481.0  2.096438e+09     6846.0     3.062281e+09             NaN
# 26  2048     481.0  2.117402e+09     6846.0     3.092904e+09             NaN
# 27  2049     481.0  2.138576e+09     6846.0     3.123833e+09             NaN
# 28  2050     481.0  2.159962e+09     6846.0     3.155072e+09             NaN
# 29  2051     481.0  2.181562e+09     6846.0     3.186622e+09             NaN
# 30  2052     481.0  2.203377e+09     6846.0     3.218489e+09             NaN
# 31  2053     481.0  2.225411e+09     6846.0     3.250673e+09             NaN
# 32  2054     481.0  2.247665e+09     6846.0     3.283180e+09             NaN
# 33  2055     481.0  2.270142e+09     6846.0     3.316012e+09             NaN
# 34  2056     481.0  2.292843e+09     6846.0     3.349172e+09             NaN
#
#                 Unnamed: 6
# 0   << aliquota ou aportes
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# 32                     NaN
# 33                     NaN
# 34                     NaN

# %%
#para aliquotas postecipadas
time.sleep(3)
    
for i, celula in enumerate(df["ano"]):
    ano = df.loc[i, "ano"]
    taxa = df.loc[i, "tx_juros"]
    aportes = df.loc[i, "aportes"]
    aliquotas = df.loc[i, "aliquotas"]
    base_de_calculo = df.loc[i, "base_de_calculo"]
    
    pyperclip.copy(str(ano))
    
    pyautogui.hotkey('ctrl','v')
    pyautogui.press('tab')
    
    pyperclip.copy(str(taxa))
    
    pyautogui.hotkey('ctrl','v')
    pyautogui.press('tab')
    
    #pyperclip.copy(str(aportes))
    
    #pyautogui.hotkey('ctrl','v')
    #pyautogui.press('tab')
    
    pyperclip.copy(str(aliquotas))
    
    pyautogui.hotkey('ctrl','v')
    pyautogui.press('tab')
    
    pyperclip.copy(str(base_de_calculo))
    
    pyautogui.hotkey('ctrl','v')
    pyautogui.press('tab')
    
    pyautogui.press('enter')
    pyautogui.hotkey('shift','tab')
    pyautogui.hotkey('shift','tab')
    pyautogui.hotkey('shift','tab')
    pyautogui.hotkey('shift','tab')
