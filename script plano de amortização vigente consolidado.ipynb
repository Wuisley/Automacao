# %%
#!pip install pyautogui
#!pip install opencv-python
#!pip install Openpyxl
#!pip install workbook
#!pip install pandas
#!pip install pywin32
#!pip install pyinstaller (para deixar o script executável)

# %%
import openpyxl as py
import pyautogui
import pyperclip #para conseguir usar texto com caracteres especiais
import time #para conseguir dar pausa em uma etapa específica
import pandas as pd
import pyperclip as pyper
#pyautogui.PAUSE = 1

# %%
df = pd.read_excel('plano de amortização.xlsx', sheet_name=0)
display(df)

tipo = df.loc[0,'tipo_amort_vigente']
tipo
# Out:
#      ano       aportes  perc_folha_pag  perc_cadprev tipo_amort_vigente  \
# 0   2021  3.533953e+07         0.47300        47.300             aporte
# 1   2022  3.533953e+07         0.47300        47.300                NaN
# 2   2023  3.533953e+07         0.47300        47.300                NaN
# 3   2024  3.533953e+07         0.52460        52.460                NaN
# 4   2025  3.533953e+07         0.53100        53.100                NaN
# 5   2026  3.533953e+07         0.53741        53.741                NaN
# 6   2027  3.533953e+07         0.54380        54.380                NaN
# 7   2028  3.533953e+07         0.55020        55.020                NaN
# 8   2029  3.533953e+07         0.55650        55.650                NaN
# 9   2030  3.533953e+07         0.56290        56.290                NaN
# 10  2031  3.533953e+07         0.56930        56.930                NaN
# 11  2032  3.533953e+07         0.57570        57.570                NaN
# 12  2033  3.533953e+07         0.58210        58.210                NaN
# 13  2034  3.533953e+07         0.58840        58.840                NaN
# 14  2035  3.533953e+07         0.59480        59.480                NaN
# 15  2036  3.533953e+07         0.59480        59.480                NaN
# 16  2037  3.533953e+07         0.59480        59.480                NaN
# 17  2038  3.533953e+07         0.59480        59.480                NaN
# 18  2039  3.533953e+07         0.59480        59.480                NaN
# 19  2040  3.533953e+07         0.59480        59.480                NaN
# 20  2041  3.533953e+07         0.59480        59.480                NaN
# 21  2042  3.533953e+07         0.59480        59.480                NaN
# 22  2043  3.533953e+07         0.59480        59.480                NaN
# 23  2044  3.533953e+07         0.59480        59.480                NaN
# 24  2045  3.533953e+07         0.59480        59.480                NaN
# 25  2046  3.533953e+07         0.59480        59.480                NaN
# 26  2047  3.533953e+07         0.59480        59.480                NaN
# 27  2048  3.533953e+07         0.59480        59.480                NaN
# 28  2049  3.533953e+07         0.59480        59.480                NaN
# 29  2050  3.533953e+07         0.59480        59.480                NaN
# 30  2051  3.533953e+07         0.59480        59.480                NaN
# 31  2052  3.533953e+07         0.59480        59.480                NaN
# 32  2053  3.533953e+07         0.59480        59.480                NaN
# 33  2054  3.533953e+07         0.59480        59.480                NaN
# 34  2055  3.533953e+07         0.59480        59.480                NaN
#
#                 Unnamed: 5
# 0   <<< aporte ou aliquota
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# 32                     NaN
# 33                     NaN
# 34                     NaN
# 'aporte'

# %%
#para aliquotas

if tipo == 'aliquota' :

    time.sleep(2)

    for i, celula in enumerate(df["ano"]):
        ano = df.loc[i, "ano"]
        aportes = df.loc[i, "aportes"]
        aliquota = df.loc[i, "perc_cadprev"]
        
        pyperclip.copy(str(ano))
        
        pyautogui.hotkey('ctrl','v')
        pyautogui.press('tab')
        
        #pyperclip.copy(str(aportes))
        
        #pyautogui.hotkey('ctrl','v')
        #pyautogui.press('tab')
        
        pyperclip.copy(str(aliquota))
        
        pyautogui.hotkey('ctrl','v')
        pyautogui.press('tab')
        pyautogui.press('tab')
        
        pyautogui.press('enter')
        pyautogui.hotkey('shift','tab')
        pyautogui.hotkey('shift','tab')
        pyautogui.hotkey('shift','tab')

else:
    #para aportes
    time.sleep(2)
    
    for i, celula in enumerate(df["ano"]):
        ano = df.loc[i, "ano"]
        aportes = df.loc[i, "aportes"]
        aliquota = df.loc[i, "perc_cadprev"]
        
        pyperclip.copy(str(ano))
        
        pyautogui.hotkey('ctrl','v')
        pyautogui.press('tab')
        
        #pyperclip.copy(str(aliquota))
        
        #pyautogui.hotkey('ctrl','v')
        pyautogui.press('tab')
        
        
        pyperclip.copy(str(aportes))
        
        pyautogui.hotkey('ctrl','v')
        pyautogui.press('tab')
        
        pyautogui.press('enter')
        pyautogui.hotkey('shift','tab')
        pyautogui.hotkey('shift','tab')
        pyautogui.hotkey('shift','tab')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 56
#      53 pyperclip.copy(str(aportes))
#      55 pyautogui.hotkey('ctrl','v')
# ---> 56 pyautogui.press('tab')
#      58 pyautogui.press('enter')
#      59 pyautogui.hotkey('shift','tab')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyautogui\__init__.py:599, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     597 failSafeCheck()
#     598 returnVal = wrappedFunction(*args, **kwargs)
# --> 599 _handlePause(kwargs.get("_pause", True))
#     600 return returnVal
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyautogui\__init__.py:643, in _handlePause(_pause)
#     641 if _pause:
#     642     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 643     time.sleep(PAUSE)
#
# KeyboardInterrupt:
