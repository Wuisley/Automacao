# %%
import pandas as pd
import pyautogui

# %%
df = pd.read_excel('plano de amortização.xlsx', sheet_name = 5)
df
# Out:
#               órgão  Número órgão  Número Critério  \
# 0   junta comercial             3                1
# 1   junta comercial             3                1
# 2   junta comercial             3                1
# 3   junta comercial             3                1
# 4   junta comercial             3                1
# 5   junta comercial             3                1
# 6   junta comercial             3                1
# 7   junta comercial             3                1
# 8   junta comercial             3                1
# 9   junta comercial             3                1
# 10       Assembleia             4                1
# 11       Assembleia             4                1
# 12       Assembleia             4                1
# 13       Assembleia             4                1
# 14       Assembleia             4                1
# 15       Assembleia             4                1
# 16       Assembleia             4                1
# ...

# %%
teste = df.loc[df['Número órgão']== 3]
teste
# Out:
#              órgão  Número órgão  Número Critério  \
# 0  junta comercial             3                1
# 1  junta comercial             3                1
# 2  junta comercial             3                1
# 3  junta comercial             3                1
# 4  junta comercial             3                1
# 5  junta comercial             3                1
# 6  junta comercial             3                1
# 7  junta comercial             3                1
# 8  junta comercial             3                1
# 9  junta comercial             3                1
#
#                                          Critério    Tipo    Carreira  \
# 0  Sem critério diferenciado para a aposentadoria  Ativos  MAGISTRADO
# 1  Sem critério diferenciado para a aposentadoria  Ativos  MAGISTRADO
# 2  Sem critério diferenciado para a aposentadoria  Ativos        PROF
# 3  Sem critério diferenciado para a aposentadoria  Ativos        PROF
# ...

# %%
teste2 = teste[['Número Critério', 'Carreira', 'SEXO']]
teste2
# Out:
#    Número Critério    Carreira SEXO
# 0                1  MAGISTRADO    M
# 1                1  MAGISTRADO    F
# 2                1        PROF    M
# 3                1        PROF    F
# 4                1     MILITAR    M
# 5                1     MILITAR    F
# 6                1      OUTROS    M
# 7                1      OUTROS    F
# 8                1    PROF SUP    M
# 9                1    PROF SUP    F
